# %%
from dask_jobqueue import PBSCluster
from dask.distributed import Client, metrics, wait
# wait for jobs to arrive, depending on the queue, this may take some time
import dask.array as da
import dask.bag as db
import numpy as np
from dask.diagnostics import Profiler, ResourceProfiler, CacheProfiler, progress
import os
from matplotlib import use
use('agg')
os.environ['PROJ_LIB'] = '/home/zsherman/anaconda3/envs/cmac_env/share/proj/'
import pyart
import netCDF4
import tarfile
import tempfile
import shutil
from netCDF4 import num2date
import json
from time import strftime, sleep
import os
# %matplotlib inline
import argparse
import datetime
import glob
import importlib
import subprocess
import time

from cmac import (cmac, get_cmac_values, quicklooks,
                  get_sounding_times, get_sounding_file_name)
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# /home/zsherman/pyart/pyart/graph/cm.py:104: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'red' in spec:
# /home/zsherman/pyart/pyart/graph/cm_colorblind.py:32: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'red' in spec:
# /home/zsherman/anaconda3/envs/cmac_env/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def run_cmac_and_plotting(
    radar_file_path, sounding_times, config, clutter_file, out_radar, image_directory, bad_directory, meta_append,
    overwrite, dd_lobes):
    """ For dask we need the radar plotting routines all in one subroutine. """
    cmac_config = get_cmac_values(config)

    try:
        radar = pyart.io.read(radar_file_path)
    except TypeError:
        if bad_directory is None:
            path = os.path.expanduser('~') + '/' + 'type_error_radars/'
        else:
            path = bad_directory
        print(radar_file_path + ' has encountered TypeError!')
        if not os.path.exists(path):
            os.makedirs(path)
            subprocess.call('chmod -R g+rw ' + path, shell=True)
        shutil.move(radar_file_path, path)
        return

    radar_start_date = netCDF4.num2date(radar.time['data'][0],
                                        radar.time['units'])
    year_str = "%04d" % radar_start_date.year
    month_str = "%02d" % radar_start_date.month
    day_str = "%02d" % radar_start_date.day
    hour_str = "%02d" % radar_start_date.hour
    minute_str = "%02d" % radar_start_date.minute
    second_str = "%02d" % radar_start_date.second

    save_name = cmac_config['save_name']
    if out_radar is None:
        the_path = (os.path.expanduser('~') + '/'+ year_str + month_str
                    + second_str + '/')
    else:
        the_path = (out_radar + '/' + year_str +  month_str
                    + day_str)
    file_name = (the_path + '/' + save_name + '.'
                 + year_str + month_str + day_str + '.' + hour_str
                 + minute_str + second_str + '.nc')

    # If overwrite is False, checks to see if the cmac_radar file
    # already exists. If so, CMAC 2.0 is not used on the original radar file.
    if overwrite is False and os.path.exists(file_name) is True:
        print(file_name + ' already exists.')
        return

    if not os.path.exists(the_path):
        os.makedirs(the_path)
        subprocess.call('chmod -R g+rw ' + the_path, shell=True)

    # Load clutter files.
    if clutter_file is not None:
        clutter_file_path = clutter_file
        if verbose:
            print('## Loading clutter file ' + clutter_file_path)
        clutter = pyart.io.read(clutter_file_path)
        if verbose:
            print('## Reading dictionary...')
        clutter_field_dict = clutter.fields['xsapr_clutter']
        if verbose:
            print('## Adding clutter field..')
        radar.add_field(
            'xsapr_clutter', clutter_field_dict, replace_existing=True)
        del clutter

    # Retrieve closest sonde in time to the time of the radar file.
    sonde_name = cmac_config['sonde_name']
    closest_time = min(
        sounding_times, key=lambda d: abs(d - radar_start_date))
    sonde_file = get_sounding_file_name(
        sonde_path, sonde_name, closest_time)
    sonde = netCDF4.Dataset(sonde_file)

    try:
        # Running the cmac code to produce a cmac_radar object.
        cmac_radar = cmac(radar, sonde, config, flipped_velocity=False,
                          meta_append=meta_append,
                          verbose=verbose)
    except ValueError:
        del radar
        sonde.close()
        return

    # Free up some memory.
    del radar
    sonde.close()

    # Produce the cmac_radar file from the cmac_radar object.
    pyart.io.write_cfradial(file_name, cmac_radar)
    print('## A CMAC radar object has been created at ' + file_name)

    # Providing the image_directory and checking if it already exists.
    img_directory = (image_directory + '/' + year_str + month_str
                     + day_str + '.' + hour_str + minute_str + second_str)
    if not os.path.exists(img_directory):
        os.makedirs(img_directory)
        subprocess.call('chmod -R g+rw ' + img_directory, shell=True)

    # Producing all the cmac_radar quicklooks.
    quicklooks(cmac_radar, config,
               image_directory=img_directory,
               dd_lobes=dd_lobes)

    # Delete the cmac_radar object and move on to the next radar file.
    del cmac_radar
    return

# %%
radar_path = '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/'
sonde_path = '/lustre/or-hydra/cades-arm/proj-shared/CACTI-sounding-testing/'
config = 'cacti_csapr2_ppi'

# %%
cmac_config = get_cmac_values(config)
sonde_name = cmac_config['sonde_name']
if os.path.isdir(radar_path):
    radar_files = glob.glob(radar_path + '*')
elif os.path.isfile(radar_path):
    with open(radar_path) as f:
        radar_files = f.readlines()
    radar_files = [x.strip() for x in radar_files]
else:
    raise IOError('The specified radar path does not exist!')

sounding_times = get_sounding_times(sonde_path, sonde_name)

# Get dates of radar files from the file name.
#radar_times = []
#for file_name in radar_files:
 #   where_x = file_name.find(x_compass)
  #  radar_times.append(
   #     datetime.datetime.strptime(file_name[where_x+3:where_x+15],
    #                               '%y%m%d%H%M%S'))

# %%
radar_files
# Out:
# ['/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.154503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.151506.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.170003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.063003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.203003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.151503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.131503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.110005.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.180003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.181503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.144503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.073003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.160003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.111740.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.115312.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.200003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.031503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.081503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.034503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.103003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.010003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.000003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.025756.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.015300.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.055843.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.051503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.194503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.151503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.063003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.050356.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.073003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.173004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.181503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.184503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.131503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.031504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.164503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.010003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.103003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.081503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.034503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.031503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.200003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.051503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.040850.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.224554.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.113003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.000003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.144503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.044504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.110003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.073003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.194503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.121503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.103425.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.124503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.170003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.013003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.094503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.051503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.091503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.070003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.113003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.044503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.081503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.221503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.010003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.085553.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.173003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.041503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.131503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.052736.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.110003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.073003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.084617.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.144503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.170003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.013003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.124503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.194503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.121503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.070003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.113003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.091503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.051503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.094503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.210003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.103025.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.070539.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.200003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.041503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.224503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.010003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.173003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.081503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.044503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.020003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.232035.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.123003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.014503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.011503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.012325.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.140003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.164503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.073003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.173004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.093003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.063409.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.223003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.192527.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.171503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.183004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.194503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.043003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.150003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.174503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.020003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.133003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.020856.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.011503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.010003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.021040.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.014503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.123003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.180003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.093003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.140003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.043003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.194503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.080012.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.190003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.171503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.170003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.061503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.080003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.201503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.200003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.153003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.064503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.050003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.133003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.071500.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.183003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.171507.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.150003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.033003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.104503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.101503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.122041.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.084008.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.132323.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.180003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.130003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.221734.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.164503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.064504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.093151.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.064503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.153003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.204503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.080003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.081503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.064319.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.061503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.183003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.160145.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.000440.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.171504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.230003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.104504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.050003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.135454.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.033004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.133003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.101503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.003611.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.104503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.150003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.033003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.153012.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.083347.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.011049.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.164503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.130003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.153004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.180003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.230450.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.153003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.040003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.064503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.011503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.221503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.220149.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.180004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.080003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.070003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.090003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.010740.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.033720.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.050003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.143003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.074503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.223003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.120003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.203003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.033003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.104503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.023003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.114503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.042435.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.181503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.193003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.080003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.221503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.011503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.173003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.164504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.064503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.201503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.040003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.074503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.035305.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.143003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.094503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.050003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.211503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.090003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.183003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.011516.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.012439.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.130737.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.104503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.033003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.120003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.171503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.013003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.223003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.223320.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.031341.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.114503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.120455.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.130003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.023003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.133003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.050003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.113727.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.001503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.183003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.011503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.221503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.080003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.053004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.153003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.122022.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.201503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.064503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.094309.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.161503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.181503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.180003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.061136.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.130003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.030538.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.164503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.203003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.033003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.150003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.104503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.003919.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.040055.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.171503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.083004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.183003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.001503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.133003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.050003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.064503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.105011.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.153003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.201503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.080003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.101840.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.002025.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.011503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.164503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.130003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.180003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.073709.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.233003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.223003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.104503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.033003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.203003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.150003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.022441.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.131503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.044811.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.134503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.181503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.110003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.003003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.013003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.100003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.223003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.151503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.051504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.203003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.151501.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.183003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.054503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.163003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.065902.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.070003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.223002.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.113325.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.234503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.194504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.013910.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.094503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.050003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.051503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.200003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.201503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.031503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.084503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.044503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.081503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.090215.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.060003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.173003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.003003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.110003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.134503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.181503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.200004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.131503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.203003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.100003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.013003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.124503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.152321.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.051503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.094503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.170004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.070003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.231503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.054503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.080839.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.221503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.060003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.195657.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.081503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.044503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.031503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.201503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.084503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.000749.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.151503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.194503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.124503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.013003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.223003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.170003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.144503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.073003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.110003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.194112.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.141503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.200004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.044503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.123607.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.221503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.010003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.025257.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.201503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.031503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.021503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.094503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.113003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.070003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.223003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.113004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.013003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.170003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.171503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.124503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.191503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.081802.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.203003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.141503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.213003.nc',
# ...
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.191504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.091503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.113003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.120428.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.000003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.210003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.021503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.043003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.121503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.170003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.063003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.231504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.154503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.191503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.190003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.073003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.160003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.144503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.213003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.141503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.103003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.010003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.204503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.034503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.041503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.091139.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.224503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.075254.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.021503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.210003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.000003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.113003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.230003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.091503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.024503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.061503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.161504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.220003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.193003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.204503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.040003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.123003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.023004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.224503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.114504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.014503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.233620.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.020003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.210003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.143003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.074503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.230003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.214503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.091503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.090003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.120003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.043003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.174503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.101503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.190003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.093003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.193004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.214604.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.140003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.023003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.114503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.014503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.224503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.164612.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.040003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.123003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.193003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.061503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.233004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.090003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.191504.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.051942.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.230003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.071503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.074503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.210003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.211503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.020003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.143003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.190003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.101503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.114910.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.174503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.120003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.043003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.114503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.040004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.140003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.023003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.032925.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.093003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.111503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.000003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.001503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.230003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.020003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.133003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.123003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180925.110557.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.014503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.061503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.204503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.160003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.161503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.180003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.093003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.101503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.154503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.190003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.055112.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.150003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.043003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180924.235204.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.004503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.133003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.210003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.020003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.230003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.001503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.000003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.204503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181004.061503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.014503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.224503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.030003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181001.193004.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181007.093003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181008.233003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181009.161503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.164503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.140003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.053003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181003.184503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.174503.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181006.043003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181010.150003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20180926.024210.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181011.083003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181002.063003.nc',
#  '/lustre/or-hydra/cades-arm/proj-shared/CACTI-csapr2-ingested/corcsapr2cfrppiM1.a1.20181005.101503.nc']

# %%
sounding_times
# Out:
# [datetime.datetime(2018, 10, 2, 16, 1),
#  datetime.datetime(2018, 10, 14, 16, 1),
#  datetime.datetime(2018, 10, 9, 20, 0),
#  datetime.datetime(2018, 10, 2, 12, 43),
#  datetime.datetime(2018, 9, 28, 12, 22),
#  datetime.datetime(2018, 10, 5, 16, 0),
#  datetime.datetime(2018, 10, 5, 12, 0),
#  datetime.datetime(2018, 10, 1, 12, 50),
#  datetime.datetime(2018, 10, 1, 11, 59),
#  datetime.datetime(2018, 10, 17, 0, 0),
#  datetime.datetime(2018, 10, 1, 19, 59),
#  datetime.datetime(2018, 10, 14, 12, 0),
#  datetime.datetime(2018, 10, 3, 23, 57),
#  datetime.datetime(2018, 10, 10, 11, 59),
#  datetime.datetime(2018, 10, 10, 0, 0),
#  datetime.datetime(2018, 10, 10, 19, 59),
#  datetime.datetime(2018, 9, 28, 12, 56),
#  datetime.datetime(2018, 10, 1, 15, 58),
#  datetime.datetime(2018, 10, 9, 16, 0),
#  datetime.datetime(2018, 10, 9, 12, 0),
#  datetime.datetime(2018, 10, 8, 0, 0),
#  datetime.datetime(2018, 10, 8, 19, 59),
#  datetime.datetime(2018, 10, 15, 0, 0),
#  datetime.datetime(2018, 10, 16, 20, 0),
#  datetime.datetime(2018, 10, 7, 12, 0),
#  datetime.datetime(2018, 10, 7, 16, 0),
#  datetime.datetime(2018, 10, 10, 23, 57),
#  datetime.datetime(2018, 10, 12, 15, 59),
#  datetime.datetime(2018, 10, 12, 11, 59),
#  datetime.datetime(2018, 10, 7, 20, 0),
#  datetime.datetime(2018, 10, 11, 20, 0),
#  datetime.datetime(2018, 10, 4, 19, 59),
#  datetime.datetime(2018, 10, 12, 0, 0),
#  datetime.datetime(2018, 10, 16, 12, 0),
#  datetime.datetime(2018, 10, 16, 16, 0),
#  datetime.datetime(2018, 10, 5, 20, 2),
#  datetime.datetime(2018, 10, 4, 23, 58),
#  datetime.datetime(2018, 10, 6, 20, 0),
#  datetime.datetime(2018, 10, 13, 19, 59),
#  datetime.datetime(2018, 10, 13, 0, 0),
#  datetime.datetime(2018, 10, 13, 15, 59),
#  datetime.datetime(2018, 10, 13, 11, 59),
#  datetime.datetime(2018, 9, 27, 14, 9),
#  datetime.datetime(2018, 10, 13, 23, 58),
#  datetime.datetime(2018, 10, 2, 19, 58),
#  datetime.datetime(2018, 10, 9, 0, 0),
#  datetime.datetime(2018, 10, 17, 12, 1),
#  datetime.datetime(2018, 10, 6, 12, 0),
#  datetime.datetime(2018, 10, 10, 16, 0),
#  datetime.datetime(2018, 10, 6, 16, 0),
#  datetime.datetime(2018, 10, 2, 0, 0),
#  datetime.datetime(2018, 10, 14, 19, 59),
#  datetime.datetime(2018, 10, 12, 20, 0),
#  datetime.datetime(2018, 10, 7, 0, 0),
#  datetime.datetime(2018, 10, 11, 11, 59),
#  datetime.datetime(2018, 10, 15, 16, 0),
#  datetime.datetime(2018, 10, 3, 16, 0),
#  datetime.datetime(2018, 10, 15, 12, 0),
#  datetime.datetime(2018, 10, 8, 16, 0),
#  datetime.datetime(2018, 10, 8, 12, 0),
#  datetime.datetime(2018, 10, 3, 20, 1),
#  datetime.datetime(2018, 10, 11, 15, 58),
#  datetime.datetime(2018, 10, 3, 12, 1),
#  datetime.datetime(2018, 10, 16, 0, 0),
#  datetime.datetime(2018, 10, 15, 20, 0),
#  datetime.datetime(2018, 10, 2, 11, 57),
#  datetime.datetime(2018, 10, 5, 23, 57),
#  datetime.datetime(2018, 10, 4, 16, 0),
#  datetime.datetime(2018, 10, 4, 12, 0)]

# %%
bad_directory = None
out_radar = '/lustre/or-hydra/cades-arm/proj-shared/cacticsapr2cmacppi.c1'
image_directory = '/lustre/or-hydra/cades-arm/proj-shared/cacticsapr2cmacppi.c1.png'
meta_append = 'config'
overwrite = True
clutter_file = None
verbose = False
dd_lobes = False

# %%
#cluster = PBSCluster(name='dask-worker', memory='270GB', cores=36, processes=6, interface='ib0', queue='high_mem', project='arm',
#                    walltime='00:30:00')#, job-extra=['-W group_list=cades-arm'])
cluster1 = PBSCluster(processes=16, cores=16, walltime='6:00:00', queue='batch')
cluster1.scale(2*16)         # Ask for ten workers
client1 = Client(cluster1)  # Connect this local process to remote workers
# Out:
# /home/zsherman/anaconda3/envs/cmac_env/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/zsherman/anaconda3/envs/cmac_env/lib/python3.6/site-packages/tornado/concurrent.py:521: DeprecationWarning: @return_future is deprecated, use coroutines instead
#   DeprecationWarning)
# /home/zsherman/anaconda3/envs/cmac_env/lib/python3.6/site-packages/distributed/bokeh/core.py:56: UserWarning:
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the diagnostics dashboard on a random port instead.
#   warnings.warn('\n' + msg)

# %%
cluster1
# Out:
# VBox(children=(HTML(value='<h2>PBSCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .d…

# %%
client1
# Out:
# <Client: scheduler='tcp://10.23.216.82:45154' processes=32 cores=32>

# %%
def com():
    os.environ['PROJ_LIB'] = '/home/zsherman/anaconda3/envs/cmac_env/share/proj/'
    from mpl_toolkits.basemap import Basemap
    return os.environ['PROJ_LIB']
client1.run(com)
# Out:
# {'tcp://10.23.216.184:33689': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:34727': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:37648': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:39140': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:39796': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:40689': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:41185': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:42933': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:43478': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:48689': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:50137': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:51351': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:54921': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:57238': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:57595': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.184:57597': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:33180': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:39863': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:40485': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:42568': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:42765': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:43255': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:44108': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:45541': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:46254': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:49458': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:49716': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:50012': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:52258': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:52640': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:53860': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/',
#  'tcp://10.23.216.186:56132': '/home/zsherman/anaconda3/envs/cmac_env/share/proj/'}

# %%
the_bag = db.from_sequence(radar_files)
the_function = lambda x: run_cmac_and_plotting(
    x, sounding_times=sounding_times, config='cacti_csapr2_ppi',
    clutter_file=clutter_file, out_radar=out_radar, image_directory=image_directory,
    bad_directory=bad_directory, meta_append=meta_append,
    overwrite=overwrite, dd_lobes=dd_lobes)
futures1 = the_bag.map(the_function)

# %%
#start computation in the background
futures1.compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-bfc2d65b2de1> in <module>()
#       1 #start computation in the background
# ----> 2 futures1.compute()
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     393     keys = [x.__dask_keys__() for x in collections]
#     394     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 395     results = schedule(dsk, keys, **kwargs)
#     396     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     397
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, **kwargs)
#    2216             try:
#    2217                 results = self.gather(packed, asynchronous=asynchronous,
# -> 2218                                       direct=direct)
#    2219             finally:
#    2220                 for f in futures.values():
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, maxsize, direct, asynchronous)
#    1579             return self.sync(self._gather, futures, errors=errors,
#    1580                              direct=direct, local_worker=local_worker,
# -> 1581                              asynchronous=asynchronous)
#    1582
#    1583     @gen.coroutine
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/site-packages/distributed/client.py in sync(self, func, *args, **kwargs)
#     645             return future
#     646         else:
# --> 647             return sync(self.loop, func, *args, **kwargs)
#     648
#     649     def __repr__(self):
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, *args, **kwargs)
#     273     else:
#     274         while not e.is_set():
# --> 275             e.wait(10)
#     276     if error[0]:
#     277         six.reraise(*error[0])
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/cmac_env/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
cluster1.stop_all_jobs()

# %%
radar_path = '/lustre/or-hydra/cades-arm/proj-shared/cmac_sgpxsaprppiI5.00/201810/'
sonde_path = '/lustre/or-hydra/cades-arm/proj-shared/sgpsondewnpnC1.b1/'
config = 'xsapr_i5_ppi'

# %%
cmac_config = get_cmac_values(config)

x_compass = cmac_config['x_compass']
if os.path.isdir(radar_path):
    radar_files = glob.glob(radar_path + '/**/*' + x_compass
                            + '*', recursive=True)
elif os.path.isfile(radar_path):
    with open(radar_path) as f:
        radar_files = f.readlines()
    radar_files = [x.strip() for x in radar_files]
else:
    raise IOError('The specified radar path does not exist!')

sounding_times = get_sounding_times(sonde_path)

# Get dates of radar files from the file name.
radar_times = []
for file_name in radar_files:
    where_x = file_name.find(x_compass)
    radar_times.append(
        datetime.datetime.strptime(file_name[where_x+3:where_x+15],
                                   '%y%m%d%H%M%S'))

# %%
bad_directory = None
out_radar = '/lustre/or-hydra/cades-arm/proj-shared/sgpxsaprcmacsurI5.c1'
image_directory = '/lustre/or-hydra/cades-arm/proj-shared/sgpxsaprcmacsurI5.c1.png'
meta_append = 'config'
overwrite = False
clutter_file = None
verbose = False
dd_lobes = False

# %%
#cluster = PBSCluster(name='dask-worker', memory='270GB', cores=36, processes=6, interface='ib0', queue='high_mem', project='arm',
#                    walltime='00:30:00')#, job-extra=['-W group_list=cades-arm'])
cluster2 = PBSCluster(processes=16, cores=16, walltime='4:00:00')
cluster2.scale(16*16)         # Ask for ten workers
client2 = Client(cluster2)  # Connect this local process to remote workers

# %%
print(cluster2.job_script())

# %%
cluster2

# %%
client2

# %%
def com():
    os.environ['PROJ_LIB'] = '/home/zsherman/anaconda3/envs/cmac_env/share/proj/'
    from mpl_toolkits.basemap import Basemap
    return os.environ['PROJ_LIB']
client2.run(com)

# %%
the_bag = db.from_sequence(radar_files)
the_function = lambda x: run_cmac_and_plotting(
    x, sounding_times=sounding_times, config='xsapr_i5_ppi',
    clutter_file=clutter_file, out_radar=out_radar, image_directory=image_directory,
    bad_directory=bad_directory, meta_append=meta_append,
    overwrite=overwrite, dd_lobes=dd_lobes)
futures2 = the_bag.map(the_function)

# %%
#start computation in the background
futures2.compute()# watch progress

# %%
cluster2.stop_all_jobs()

# %%
radar_path = '/lustre/or-hydra/cades-arm/proj-shared/sgpxsaprsecI6.00/201808/'
sonde_path = '/lustre/or-hydra/cades-arm/proj-shared/sgpsondewnpnC1.b1/'
config = 'xsapr_i6_sec'

# %%
cmac_config = get_cmac_values(config)

x_compass = cmac_config['x_compass']
if os.path.isdir(radar_path):
    radar_files = glob.glob(radar_path + '/**/*' + x_compass
                            + '*', recursive=True)
elif os.path.isfile(radar_path):
    with open(radar_path) as f:
        radar_files = f.readlines()
    radar_files = [x.strip() for x in radar_files]
else:
    raise IOError('The specified radar path does not exist!')

sounding_times = get_sounding_times(sonde_path)

# Get dates of radar files from the file name.
radar_times = []
for file_name in radar_files:
    where_x = file_name.find(x_compass)
    radar_times.append(
        datetime.datetime.strptime(file_name[where_x+3:where_x+15],
                                   '%y%m%d%H%M%S'))

# %%
bad_directory = None
out_radar = '/lustre/or-hydra/cades-arm/proj-shared/sgpxsaprcmacsecI6.c1'
image_directory = '/lustre/or-hydra/cades-arm/proj-shared/sgpxsaprcmacsecI6.c1.png'
meta_append = 'config'
overwrite = False
clutter_file = None
verbose = False
dd_lobes = False

# %%
#cluster = PBSCluster(name='dask-worker', memory='270GB', cores=36, processes=6, interface='ib0', queue='high_mem', project='arm',
#                    walltime='00:30:00')#, job-extra=['-W group_list=cades-arm'])
cluster3 = PBSCluster(processes=36, cores=36, walltime='09:00:00',
                      scheduler_file='/home/zsherman/scheduler.json')
cluster3.scale(10)         # Ask for ten workers
client3 = Client(cluster3)  # Connect this local process to remote workers

# %%
cluster3

# %%
client3

# %%
def com():
    os.environ['PROJ_LIB'] = '/home/zsherman/anaconda3/envs/cmac_env/share/proj/'
    from mpl_toolkits.basemap import Basemap
    return os.environ['PROJ_LIB']
client3.run(com)

# %%
the_bag = db.from_sequence(radar_files)
the_function = lambda x: run_cmac_and_plotting(
    x, sounding_times=sounding_times, config='xsapr_i6_sec',
    clutter_file=clutter_file, out_radar=out_radar, image_directory=image_directory,
    bad_directory=bad_directory, meta_append=meta_append,
    overwrite=overwrite, dd_lobes=dd_lobes)
futures3 = the_bag.map(the_function)

# %%
#start computation in the background
futures3.compute()# watch progress

# %%
#print('## Opened dask cluster with ' + str(n_cores) + ' cores')

#the_bag = db.from_sequence(radar_files)
#the_function = lambda x: run_cmac_and_plotting(
#    x, sounding_times, args)
#result = the_bag.map(the_function).compute()

## Do radar object loading on compute nodes.
if image_directory is None:
    print('## Quicklooks have been saved in your home directory.')
else:
    print('## Quicklooks have been saved to ' + image_directory)

subprocess.call('chmod -R g+rw ' + image_directory, shell=True)
subprocess.call('chmod -R g+rw ' + out_radar, shell=True)
print('##')
print('## CMAC 2.0 Completed in ' + str(time.time() - bt) + ' s')
client.shutdown()

# %%
def manage_tarfile(path_and_file, 
                   experiment_location='/lustre/or-hydra/cades-arm/proj-shared/dask_test/formatted'):
    def examine(fh_like):
        
        radar = pyart.io.read(fh_like)
        time_start = num2date(radar.time['data'][0], radar.time['units'])
        time_end = num2date(radar.time['data'][-1], radar.time['units'])
        stype = radar.scan_type
        nsweeps = radar.nsweeps
        tgates = float(radar.ngates*radar.nrays)
        zdat = radar.fields['reflectivity']['data']
        z0 = float(len(np.where(zdat > 0.)[0]))/tgates
        z10 = float(len(np.where(zdat > 10.)[0]))/tgates
        z40 = float(len(np.where(zdat > 40.)[0]))/tgates
        rdict = {'time_start': time_start,
                 'time_end': time_end,
                 'scan_type': stype,
                 'nsweeps': nsweeps,
                 'z0': z0,
                 'z10': z10,
                 'z40': z40,
                 'expr': radar.metadata['sigmet_task_name'].lower().strip().decode("utf-8")}

        return rdict

    def site_from_name(name):
        fullname = name.split('.')[0]
        site = fullname[-2::]
        return site

    def file_formatter(stime, site, scanmode, base, expr):
        #base/year/monthday
        
        mday = stime.strftime('%m%d')
        odir = os.path.join(base,
                            expr.lower(),
                            scanmode,
                            stime.strftime('%Y'),
                            mday)
        fname1 = 'sgpxsapr' + scanmode + site + stime.strftime('.%Y%m%d.%H%M%S')
        return odir, fname1


    os.environ['PROJ_LIB'] = '/home/zsherman/anaconda3/envs/cmac_env/share/proj/'
    top_level = os.path.split(experiment_location)[0]
    tarobj = tarfile.open(path_and_file)
    site = site_from_name(path_and_file)
    members = tarobj.getmembers()
    status = []
    for member in members:
        try:
            radar_info = examine(tarobj.extractfile(member))
            odir_radars, file_name_begin = file_formatter(radar_info['time_start'], 
                                                   site, 
                                                   radar_info['scan_type'],
                                                   experiment_location,
                                                   radar_info['expr'])

            odir_json, file_name_begin = file_formatter(radar_info['time_start'], 
                                                   site, 
                                                   radar_info['scan_type'],
                                                   os.path.join(top_level, 'summary'),
                                                   radar_info['expr'])

            try:
                if not os.path.exists(odir_radars):
                    os.makedirs(odir_radars)

                if not os.path.exists(odir_json):
                    os.makedirs(odir_json)
            except: #just wait and try again..
                sleep(1)
                if not os.path.exists(odir_radars):
                    os.makedirs(odir_radars)

                if not os.path.exists(odir_json):
                    os.makedirs(odir_json)

            fullpath = os.path.join(odir_radars, file_name_begin+'.iris')

            json_dict = {}
            strconv_keys = ['z0', 'z10', 'z40', 'nsweeps']
            for key in strconv_keys:
                json_dict.update({key : str(radar_info[key])})

            json_dict.update({'start_time' : radar_info['time_start'].strftime('%Y%m%d-%H:%M:%S'),
                             'end_time' : radar_info['time_end'].strftime('%Y%m%d-%H:%M:%S')})

            json_dict.update({'original_name' : member.name,
                             'full_path' : fullpath})

            r = json.dumps(json_dict)
            loaded_r = json.loads(r)
            with open(os.path.join(odir_json, file_name_begin+'.json'), 'w') as outfile:
                json.dump(json_dict, outfile)

            #The actuall writing
            fh = tarobj.extractfile(member)

            shutil.copyfileobj(fh, open(fullpath, 'wb'))
            fh.close()
            status.append(member.name+':OK')
        except IndexError:
            status.append(member.name+':NotOK')
    return status

# %%
flist = manage_tarfile(all_fqdn[0])

# %%
#cluster = PBSCluster(name='dask-worker', memory='270GB', cores=36, processes=6, interface='ib0', queue='high_mem', project='arm',
#                    walltime='00:30:00')#, job-extra=['-W group_list=cades-arm'])
cluster = PBSCluster(processes=18)
cluster.scale(4)         # Ask for ten workers
client = Client(cluster)  # Connect this local process to remote workers

# %% [markdown]
# ```jobqueue:
#   pbs:
#     name: dask-worker
#     cores: 36
#     memory: 270GB
#     processes: 6
#     interface: ib0
#     local-directory: $localscratch
#     queue: high_mem # Can also select batch or gpu_ssd
#     project: arm
#     walltime: 00:30:00 #Adjust this to job size
#     job-extra: ['-W group_list=cades-arm']
# ```

# %%
cluster

# %%
client

# %%
def com():
    os.environ['PROJ_LIB'] = '/home/zsherman/anaconda3/envs/cmac_env/share/proj/'
    from mpl_toolkits.basemap import Basemap
    return os.environ['PROJ_LIB']
client.run(com)

# %%
future = client.map(manage_tarfile, all_fqdn)

# %%
progress(future)

# %%
my_data = client.gather(future)
flat_list = [item for sublist in my_data for item in sublist]
print(len(flat_list))
succeeded = 0
failed = 0
ff = []
SE_good = []
for item in flat_list:
    if 'NotOK' in item:
        failed +=  1
        ff.append(item)
    else:
        succeeded += 1
        if 'XSE'in item:
            SE_good.append(item)

print(succeeded)
print(failed)
